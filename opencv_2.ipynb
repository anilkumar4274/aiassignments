# %% [markdown]
# <a href="https://colab.research.google.com/github/anilkumar4274/aiassignments/blob/balasai/opencv_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !python read.py

# %%
import cv2
import matplotlib.pyplot as plt
img = cv2.imread("../images/image.jpg")
plt.imshow(img)

# %%
import matplotlib.pyplot as plt
# load image using cv2....and do processing.
img = cv2.imread("../images/image.jpg")
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
# as opencv loads in BGR format by default, we want to show it in RGB.
plt.show()

# %%
import cv2
img = cv2.imread("../images/image.jpg")
cv2.imshow('HelloWorld', img)
cv2.waitKey(0) 
cv2.destroyWindow('HelloWorld')

# %%
import cv2
img = cv2.imread("../images/image.jpg")
r,c=img.shape[0:2]
new_img = cv2.resize(img, (2*r,2*c), interpolation = cv2.INTER_CUBIC)
cv2.imwrite("resize_image.jpg", new_img) 
cv2.imshow("resize", new_img)
cv2.waitKey(0) 
cv2.destroyWindow('resize')

# %% [markdown]
# # Cropping the image

# %%
import cv2
img = cv2.imread("../images/image.jpg")
img_crop = img[0:200, 150:350]
cv2.imwrite("crop_img.jpg", img_crop) 
cv2.imshow("crop", img_crop)
cv2.waitKey(0) 
cv2.destroyWindow('resize')

# %% [markdown]
# # Translation

# %%
import cv2
import numpy as np
img = cv2.imread("../images/image.jpg") 
r,c = img.shape[:2]
M = np.float32([[1,0,100],[0,1,100]])
new_img = cv2.warpAffine(img,M,(c,r))
cv2.imwrite("translation.jpg", new_img) 
cv2.imshow("translation", new_img)
cv2.waitKey(0) 
cv2.destroyWindow('translation')

# %% [markdown]
# # Rotate

# %%
import cv2
img = cv2.imread("../images/image.jpg") 
r,c = img.shape[:2]
M = cv2.getRotationMatrix2D((c/2,r/2),90,1)
new_img = cv2.warpAffine(img,M,(c,r))
cv2.imwrite("rotate_img.jpg", new_img) 
cv2.imshow("rotate", new_img)
cv2.waitKey(0) 
cv2.destroyWindow('rotate')

# %% [markdown]
# # Thresholding

# %%
import cv2
img = cv2.imread("../images/image.jpg")
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
new_img = cv2.threshold(gray,120,255,cv2.THRESH_BINARY)
cv2.imwrite("thresholding.jpg", new_img[1]) 
cv2.imshow("thresholding", new_img[1])
cv2.waitKey(0) 
cv2.destroyWindow('thresholding')

# %% [markdown]
# # Filter

# %%
import cv2
import numpy as np
img = cv2.imread("../images/image.jpg")
ker = np.array([[1, 1, 1],[1, 1, 1],[1, 1, 1]])
new_img = cv2.filter2D(img,-1,ker)
cv2.imwrite("filter.jpg", new_img)
cv2.imshow("filter", new_img)
cv2.waitKey(0) 
cv2.destroyWindow('filter')
